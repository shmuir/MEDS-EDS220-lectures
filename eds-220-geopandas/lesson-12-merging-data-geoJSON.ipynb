# %% [markdown]
# 25 October 2023
#
# https://carmengg.github.io/eds-220-book/lectures/lesson-10-merge-data.html
# # GeoJSON
#
# Data stored as attribute-value pairs
# - point
# - linestring
# - polygon

# %% [markdown]
# # Merging Data
#
# Joining data frames and making maps with `geopandas`

# %% [markdown]
# ## Data and Data prep.
#
# We will use two datasets in this lesson. The first dataset is Natural Earth’s medium scale cultural boundaries data (1:50m). We can obtain this dataset by downloading the shapefile. Natural Earth is a public domain dataset with ready-to-use data for creating maps.
#
# The second dataset we will use is a list of Arctic communities and their location (Brook, 2023) which can be accessed through the DataONE repository. This is a GeoJSON file with the following attributes:
#
# - name: name of Arctic community,
# - population: population of Arctic community, as of 2022
# - country: country that the Arctic community falls within (see dataset metadata for the codes)
# - geoname-id: numeric codes that uniquely identify all administrative/legal and statistical geographic areas for which the Census Bureau tabulates data

# %%
import pandas as pd
import matplotlib.pyplot as plt

import geopandas as gpd

# %%
# display all column when looking at dataframes
pd.set_option("display.max.columns", None)

# %% [markdown]
# ## Countries

# %%
# import countries polygons
countries = gpd.read_file('data/50m_cultural/ne_50m_admin_0_countries.shp')
countries.head()
# Out:
#         featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0  Admin-0 country          1          3   Zimbabwe    ZWE         0      2
# 1  Admin-0 country          1          3     Zambia    ZMB         0      2
# 2  Admin-0 country          1          3      Yemen    YEM         0      2
# 3  Admin-0 country          3          2    Vietnam    VNM         0      2
# 4  Admin-0 country          5          3  Venezuela    VEN         0      2
#
#                 TYPE TLC      ADMIN ADM0_A3  GEOU_DIF    GEOUNIT GU_A3  \
# 0  Sovereign country   1   Zimbabwe     ZWE         0   Zimbabwe   ZWE
# 1  Sovereign country   1     Zambia     ZMB         0     Zambia   ZMB
# 2  Sovereign country   1      Yemen     YEM         0      Yemen   YEM
# 3  Sovereign country   1    Vietnam     VNM         0    Vietnam   VNM
# 4  Sovereign country   1  Venezuela     VEN         0  Venezuela   VEN
#
#    SU_DIF    SUBUNIT SU_A3  BRK_DIFF       NAME  NAME_LONG BRK_A3   BRK_NAME  \
# 0       0   Zimbabwe   ZWE         0   Zimbabwe   Zimbabwe    ZWE   Zimbabwe
# 1       0     Zambia   ZMB         0     Zambia     Zambia    ZMB     Zambia
# 2       0      Yemen   YEM         0      Yemen      Yemen    YEM      Yemen
# 3       0    Vietnam   VNM         0    Vietnam    Vietnam    VNM    Vietnam
# 4       0  Venezuela   VEN         0  Venezuela  Venezuela    VEN  Venezuela
#
#   BRK_GROUP  ABBREV POSTAL                         FORMAL_EN  \
# 0      None   Zimb.     ZW              Republic of Zimbabwe
# 1      None  Zambia     ZM                Republic of Zambia
# 2      None    Yem.     YE                 Republic of Yemen
# 3      None   Viet.     VN     Socialist Republic of Vietnam
# 4      None    Ven.     VE  Bolivarian Republic of Venezuela
#
#                             FORMAL_FR NAME_CIAWF NOTE_ADM0 NOTE_BRK  \
# 0                                None   Zimbabwe      None     None
# 1                                None     Zambia      None     None
# 2                                None      Yemen      None     None
# 3                                None    Vietnam      None     None
# 4  República Bolivariana de Venezuela  Venezuela      None     None
#
#        NAME_SORT NAME_ALT  MAPCOLOR7  MAPCOLOR8  MAPCOLOR9  MAPCOLOR13  \
# 0       Zimbabwe     None          1          5          3           9
# 1         Zambia     None          5          8          5          13
# 2    Yemen, Rep.     None          5          3          3          11
# 3        Vietnam     None          5          6          5           4
# 4  Venezuela, RB     None          1          3          1           4
#
#       POP_EST  POP_RANK  POP_YEAR  GDP_MD  GDP_YEAR  \
# 0  14645468.0        14      2019   21440      2019
# 1  17861030.0        14      2019   23309      2019
# 2  29161922.0        15      2019   22581      2019
# 3  96462106.0        16      2019  261921      2019
# 4  28515829.0        15      2019  482359      2014
#
#                      ECONOMY              INCOME_GRP FIPS_10 ISO_A2 ISO_A2_EH  \
# 0    5. Emerging region: G20           5. Low income      ZI     ZW        ZW
# 1  7. Least developed region  4. Lower middle income      ZA     ZM        ZM
# 2  7. Least developed region  4. Lower middle income      YM     YE        YE
# 3    5. Emerging region: G20  4. Lower middle income      VM     VN        VN
# 4    5. Emerging region: G20  3. Upper middle income      VE     VE        VE
#
#   ISO_A3 ISO_A3_EH ISO_N3 ISO_N3_EH UN_A3 WB_A2 WB_A3    WOE_ID  WOE_ID_EH  \
# 0    ZWE       ZWE    716       716   716    ZW   ZWE  23425004   23425004
# 1    ZMB       ZMB    894       894   894    ZM   ZMB  23425003   23425003
# 2    YEM       YEM    887       887   887    RY   YEM  23425002   23425002
# 3    VNM       VNM    704       704   704    VN   VNM  23424984   23424984
# 4    VEN       VEN    862       862   862    VE   VEN  23424982   23424982
#
#                      WOE_NOTE ADM0_ISO ADM0_DIFF ADM0_TLC ADM0_A3_US  \
# 0  Exact WOE match as country      ZWE      None      ZWE        ZWE
# 1  Exact WOE match as country      ZMB      None      ZMB        ZMB
# 2  Exact WOE match as country      YEM      None      YEM        YEM
# 3  Exact WOE match as country      VNM      None      VNM        VNM
# 4  Exact WOE match as country      VEN      None      VEN        VEN
#
#   ADM0_A3_FR ADM0_A3_RU ADM0_A3_ES ADM0_A3_CN ADM0_A3_TW ADM0_A3_IN  \
# 0        ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1        ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2        YEM        YEM        YEM        YEM        YEM        YEM
# 3        VNM        VNM        VNM        VNM        VNM        VNM
# 4        VEN        VEN        VEN        VEN        VEN        VEN
#
#   ADM0_A3_NP ADM0_A3_PK ADM0_A3_DE ADM0_A3_GB ADM0_A3_BR ADM0_A3_IL  \
# 0        ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1        ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2        YEM        YEM        YEM        YEM        YEM        YEM
# 3        VNM        VNM        VNM        VNM        VNM        VNM
# 4        VEN        VEN        VEN        VEN        VEN        VEN
#
#   ADM0_A3_PS ADM0_A3_SA ADM0_A3_EG ADM0_A3_MA ADM0_A3_PT ADM0_A3_AR  \
# 0        ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1        ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2        YEM        YEM        YEM        YEM        YEM        YEM
# 3        VNM        VNM        VNM        VNM        VNM        VNM
# 4        VEN        VEN        VEN        VEN        VEN        VEN
#
#   ADM0_A3_JP ADM0_A3_KO ADM0_A3_VN ADM0_A3_TR ADM0_A3_ID ADM0_A3_PL  \
# 0        ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1        ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2        YEM        YEM        YEM        YEM        YEM        YEM
# 3        VNM        VNM        VNM        VNM        VNM        VNM
# 4        VEN        VEN        VEN        VEN        VEN        VEN
#
#   ADM0_A3_GR ADM0_A3_IT ADM0_A3_NL ADM0_A3_SE ADM0_A3_BD ADM0_A3_UA  \
# 0        ZWE        ZWE        ZWE        ZWE        ZWE        ZWE
# 1        ZMB        ZMB        ZMB        ZMB        ZMB        ZMB
# 2        YEM        YEM        YEM        YEM        YEM        YEM
# 3        VNM        VNM        VNM        VNM        VNM        VNM
# 4        VEN        VEN        VEN        VEN        VEN        VEN
#
#    ADM0_A3_UN  ADM0_A3_WB      CONTINENT REGION_UN           SUBREGION  \
# 0         -99         -99         Africa    Africa      Eastern Africa
# 1         -99         -99         Africa    Africa      Eastern Africa
# 2         -99         -99           Asia      Asia        Western Asia
# 3         -99         -99           Asia      Asia  South-Eastern Asia
# 4         -99         -99  South America  Americas       South America
#
#                     REGION_WB  NAME_LEN  LONG_LEN  ABBREV_LEN  TINY  HOMEPART  \
# 0          Sub-Saharan Africa         8         8           5   -99         1
# 1          Sub-Saharan Africa         6         6           6   -99         1
# 2  Middle East & North Africa         5         5           4   -99         1
# 3         East Asia & Pacific         7         7           5     2         1
# 4   Latin America & Caribbean         9         9           4   -99         1
#
#    MIN_ZOOM  MIN_LABEL  MAX_LABEL     LABEL_X    LABEL_Y       NE_ID  \
# 0       0.0        2.5        8.0   29.925444 -18.911640  1159321441
# 1       0.0        3.0        8.0   26.395298 -14.660804  1159321439
# 2       0.0        3.0        8.0   45.874383  15.328226  1159321425
# 3       0.0        2.0        7.0  105.387292  21.715416  1159321417
# 4       0.0        2.5        7.5  -64.599381   7.182476  1159321411
#
#   WIKIDATAID   NAME_AR      NAME_BN    NAME_DE    NAME_EN    NAME_ES  \
# 0       Q954  زيمبابوي  জিম্বাবুয়ে   Simbabwe   Zimbabwe   Zimbabue
# 1       Q953    زامبيا    জাম্বিয়া     Sambia     Zambia     Zambia
# 2       Q805     اليمن      ইয়েমেন      Jemen      Yemen      Yemen
# 3       Q881    فيتنام    ভিয়েতনাম    Vietnam    Vietnam    Vietnam
# 4       Q717   فنزويلا  ভেনেজুয়েলা  Venezuela  Venezuela  Venezuela
#
#     NAME_FA    NAME_FR     NAME_EL   NAME_HE      NAME_HI    NAME_HU  \
# 0  زیمبابوه   Zimbabwe  Ζιμπάμπουε  זימבבואה  ज़िम्बाब्वे   Zimbabwe
# 1    زامبیا     Zambie      Ζάμπια     זמביה    ज़ाम्बिया     Zambia
# 2       یمن      Yémen      Υεμένη      תימן          यमन      Jemen
# 3    ویتنام   Viêt Nam     Βιετνάμ   וייטנאם      वियतनाम    Vietnám
# 4   ونزوئلا  Venezuela  Βενεζουέλα   ונצואלה   वेनेज़ुएला  Venezuela
#
#      NAME_ID    NAME_IT NAME_JA NAME_KO    NAME_NL    NAME_PL    NAME_PT  \
# 0   Zimbabwe   Zimbabwe   ジンバブエ    짐바브웨   Zimbabwe   Zimbabwe   Zimbábue
# 1     Zambia     Zambia    ザンビア     잠비아     Zambia     Zambia     Zâmbia
# 2      Yaman      Yemen    イエメン      예멘      Jemen      Jemen      Iémen
# 3    Vietnam    Vietnam    ベトナム     베트남    Vietnam    Wietnam   Vietname
# 4  Venezuela  Venezuela   ベネズエラ   베네수엘라  Venezuela  Wenezuela  Venezuela
#
#      NAME_RU    NAME_SV    NAME_TR    NAME_UK    NAME_UR    NAME_VI NAME_ZH  \
# 0   Зимбабве   Zimbabwe   Zimbabve   Зімбабве    زمبابوے   Zimbabwe    津巴布韦
# 1     Замбия     Zambia    Zambiya     Замбія     زیمبیا     Zambia     赞比亚
# 2      Йемен      Jemen      Yemen       Ємен        یمن      Yemen      也门
# 3    Вьетнам    Vietnam    Vietnam    В'єтнам     ویتنام   Việt Nam      越南
# 4  Венесуэла  Venezuela  Venezuela  Венесуела  وینیزویلا  Venezuela    委内瑞拉
#
#   NAME_ZHT       FCLASS_ISO TLC_DIFF       FCLASS_TLC FCLASS_US FCLASS_FR  \
# 0      辛巴威  Admin-0 country     None  Admin-0 country      None      None
# 1      尚比亞  Admin-0 country     None  Admin-0 country      None      None
# 2       葉門  Admin-0 country     None  Admin-0 country      None      None
# 3       越南  Admin-0 country     None  Admin-0 country      None      None
# 4     委內瑞拉  Admin-0 country     None  Admin-0 country      None      None
#
#   FCLASS_RU FCLASS_ES FCLASS_CN FCLASS_TW FCLASS_IN FCLASS_NP FCLASS_PK  \
# 0      None      None      None      None      None      None      None
# 1      None      None      None      None      None      None      None
# 2      None      None      None      None      None      None      None
# 3      None      None      None      None      None      None      None
# 4      None      None      None      None      None      None      None
#
#   FCLASS_DE FCLASS_GB FCLASS_BR FCLASS_IL FCLASS_PS FCLASS_SA FCLASS_EG  \
# 0      None      None      None      None      None      None      None
# 1      None      None      None      None      None      None      None
# 2      None      None      None      None      None      None      None
# 3      None      None      None      None      None      None      None
# 4      None      None      None      None      None      None      None
#
#   FCLASS_MA FCLASS_PT FCLASS_AR FCLASS_JP FCLASS_KO FCLASS_VN FCLASS_TR  \
# 0      None      None      None      None      None      None      None
# 1      None      None      None      None      None      None      None
# 2      None      None      None      None      None      None      None
# 3      None      None      None      None      None      None      None
# 4      None      None      None      None      None      None      None
#
#   FCLASS_ID FCLASS_PL FCLASS_GR FCLASS_IT FCLASS_NL FCLASS_SE FCLASS_BD  \
# 0      None      None      None      None      None      None      None
# 1      None      None      None      None      None      None      None
# 2      None      None      None      None      None      None      None
# 3      None      None      None      None      None      None      None
# 4      None      None      None      None      None      None      None
#
#   FCLASS_UA                                           geometry
# 0      None  POLYGON ((31.28789 -22.40205, 31.19727 -22.344...
# 1      None  POLYGON ((30.39609 -15.64307, 30.25068 -15.643...
# 2      None  MULTIPOLYGON (((53.08564 16.64839, 52.58145 16...
# 3      None  MULTIPOLYGON (((104.06396 10.39082, 104.08301 ...
# 4      None  MULTIPOLYGON (((-60.82119 9.13838, -60.94141 9...

# %%
# quick view
countries.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Arctic Communities

# %%
# re-assign the column names: .str.lower() makes them lower case
countries.columns = countries.columns.str.lower()
print(countries.columns)
# Out:
# Index(['featurecla', 'scalerank', 'labelrank', 'sovereignt', 'sov_a3',
#        'adm0_dif', 'level', 'type', 'tlc', 'admin',
#        ...
#        'fclass_tr', 'fclass_id', 'fclass_pl', 'fclass_gr', 'fclass_it',
#        'fclass_nl', 'fclass_se', 'fclass_bd', 'fclass_ua', 'geometry'],
#       dtype='object', length=169)

# %%
# remeber: the geometry column has the polygons for each country
countries_sub = countries[['admin','type','geometry']]
countries_sub.head()
# Out:
#        admin               type  \
# 0   Zimbabwe  Sovereign country
# 1     Zambia  Sovereign country
# 2      Yemen  Sovereign country
# 3    Vietnam  Sovereign country
# 4  Venezuela  Sovereign country
#
#                                             geometry
# 0  POLYGON ((31.28789 -22.40205, 31.19727 -22.344...
# 1  POLYGON ((30.39609 -15.64307, 30.25068 -15.643...
# 2  MULTIPOLYGON (((53.08564 16.64839, 52.58145 16...
# 3  MULTIPOLYGON (((104.06396 10.39082, 104.08301 ...
# 4  MULTIPOLYGON (((-60.82119 9.13838, -60.94141 9...

# %%
# read in Arctic communities data
communities = gpd.read_file('https://cn.dataone.org/cn/v2/resolve/urn%3Auuid%3Aed7718ae-fb0d-43dd-9270-fbfe80bfc7a4')
communities.head()
# Out:
#           name  population country  geoname-id                   geometry
# 0      Udomlya       32373      RU      452949  POINT (34.99250 57.87944)
# 1     Valmiera       26963      LV      453754  POINT (25.42751 57.54108)
# 2    Ventspils       42644      LV      454310  POINT (21.57288 57.38988)
# 3  Vec-Liepāja       85260      LV      454432  POINT (21.01667 56.53333)
# 4       Tukums       18348      LV      454768  POINT (23.15528 56.96694)

# %%
countries.crs == communities.crs
# Out:
# True

# %%
fig, ax = plt.subplots()
countries.plot(ax=ax)
communities.plot(ax=ax, color='red')
plt.show()

# %%
# calculate number of communities by country

# extract number of communities by country as a pd.Series
n_comms = communities.groupby('country').count().name

# convert the pd.Series into a pd.DataFrame and update it
n_comms = pd.DataFrame(n_comms).rename(columns={'name':'n_communities'}).reset_index()

# %% [markdown]
# Let’s break this down a bit:
#
# - We start with our communities dataframe and use groupby('country') to group by country code,
# then we use count() as an aggregator function to count how many rows belong to each country code.
# - The result of this operation is a dataframe (run communities.groupby('country').count() to check) and we select a single column with the counts by selecting the name column.
# - The result is a single pd.Series in the variable n_comms.
# - We then convert this pd.Series into a pd.DataFrame and clean it up a bit.

# %%
# number of communities per country
n_comms
# Out:
#    country  n_communities
# 0       AX              1
# 1       BY              8
# 2       CA              7
# 3       DK             72
# 4       EE             14
# 5       FI             98
# 6       FO              1
# 7       GB             96
# 8       GL              1
# 9       IS              5
# 10      LT             26
# 11      LV             25
# 12      NO             48
# 13      RU            774
# 14      SE            133
# 15      US            115

# %%
# select Scandinavia data
scandi_n_comms = n_comms[n_comms.country.isin(['DK','NO','SE','FO','FI','IS','AX'])].copy()
scandi_n_comms
# Out:
#    country  n_communities
# 0       AX              1
# 3       DK             72
# 5       FI             98
# 6       FO              1
# 9       IS              5
# 12      NO             48
# 14      SE            133

# %% [markdown]
# ## Merge Datasets

# %%
countries_sub.head(2)
# Out:
#       admin               type  \
# 0  Zimbabwe  Sovereign country
# 1    Zambia  Sovereign country
#
#                                             geometry
# 0  POLYGON ((31.28789 -22.40205, 31.19727 -22.344...
# 1  POLYGON ((30.39609 -15.64307, 30.25068 -15.643...

# %%
scandi_n_comms.head(2)
# Out:
#   country  n_communities
# 0      AX              1
# 3      DK             72

# %%
# Add country names 
scandi_names = ['Aland Islands',
                'Denmark',
                'Finland',
                'Faroe Islands',
                'Iceland',
                'Norway',
                'Sweden'] # can also skip this step and add this list directly into the next line
scandi_n_comms['admin'] = scandi_names 
scandi_n_comms
# Out:
#    country  n_communities          admin
# 0       AX              1  Aland Islands
# 3       DK             72        Denmark
# 5       FI             98        Finland
# 6       FO              1  Faroe Islands
# 9       IS              5        Iceland
# 12      NO             48         Norway
# 14      SE            133         Sweden

# %% [markdown]
# To merge dataframes we can use the pandas.merge() function. The basic syntax for it is:
#
# ```
# output_df = pd.merge(left_df,
#                      right_df,
#                      how = type_of_join,
#                      on = column_to_join)
# ```

# %% [markdown]
# **where**
#
# - `output_df` is the dataframe resulting from the merge,
# - `left_df` is the dataframe we have “on the left side”,
# - `right_df` is the dataframe we have “on the right side”,
# - `how` specifies the type of join between the left and right dataframes, (check the options here), the default is to do an inner join,
# - `on` specifies the column to join on, this column must be present in both our dataframes.

# %%
# merge dataframes 
scandi_countries = pd.merge(countries_sub,
                            scandi_n_comms,
                            how='inner',
                            on='admin')
# update index
scandi_countries = scandi_countries.set_index('admin')
scandi_countries
# Out:
#                             type  \
# admin
# Sweden         Sovereign country
# Norway         Sovereign country
# Iceland        Sovereign country
# Finland                  Country
# Faroe Islands         Dependency
# Denmark                  Country
#
#                                                         geometry country  \
# admin
# Sweden         MULTIPOLYGON (((19.07646 57.83594, 18.99375 57...      SE
# Norway         MULTIPOLYGON (((20.62217 69.03687, 20.49199 69...      NO
# Iceland        POLYGON ((-15.54312 66.22852, -15.42847 66.224...      IS
# Finland        MULTIPOLYGON (((24.15547 65.80527, 24.04902 65...      FI
# Faroe Islands  MULTIPOLYGON (((-6.62319 61.80596, -6.64277 61...      FO
# Denmark        MULTIPOLYGON (((12.56875 55.78506, 12.57119 55...      DK
#
#                n_communities
# admin
# Sweden                   133
# Norway                    48
# Iceland                    5
# Finland                   98
# Faroe Islands              1
# Denmark                   72

# %%
# check Aland Islands is nowhere in data frame
'Aland Islands' in countries.values
# Out:
# False

# %%
scandi_countries.at['Finland', 'n_communities'] += 1

print(scandi_countries.at['Finland', 'n_communities'])
# Out:
# 99

# %% [markdown]
# ## Choropleth map
#
# A choropleth map is an efficient way to visualize aggregate data per region.
#
# To make a choropleth map from our polygons `GeoDataFrame` we need to specify the column parameter in `plot()` and make it equal to the column with the values we want to plot in each country.

# %%
scandi_countries.plot(column='n_communities',
                      legend=True)
# Out:
# <AxesSubplot:>

# %%
## customization

fig, ax = plt.subplots(figsize=(10, 10))

scandi_countries.plot(ax=ax,
                      column='n_communities',
                       cmap='BuPu',
                       legend=True,
                       edgecolor='black',
                       legend_kwds={'shrink':.8,
                                    'label': 'Number of Arctic communities', 
                                    'orientation': 'horizontal'
                                    }
                       )


ax.set_title('Arctic communities in Scandinavia',  fontsize=20)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

plt.show()

# %% [markdown]
# # Complete Workflow

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

import geopandas as gpd

# ======= IMPORT DATA ========
# read in Arctic communities data
communities = gpd.read_file('https://cn.dataone.org/cn/v2/resolve/urn%3Auuid%3Aed7718ae-fb0d-43dd-9270-fbfe80bfc7a4')

# import countries polygons
countries = gpd.read_file('ne_50m_admin_0_countries/ne_50m_admin_0_countries.shp')
countries.head()

# ======= COMMUNITIES PREPARATION =======
# extract number of communities by country as a pd.Series
n_comms = communities.groupby('country').count().name

# convert the pd.Series into a pd.DataFrame and update it
n_comms = pd.DataFrame(n_comms).rename(columns={'name':'n_communities'}).reset_index()

# select Scandinavia data
scandi_codes = ['DK','NO','SE','FO','FI','IS','AX']
scandi_n_comms = n_comms[n_comms.country.isin(scandi_codes)].copy()

# ======= COUNTRIES PREPARATION =======
# make column names lower case
countries.columns = countries.columns.str.lower()

# names of Scandinavian countries
scandi_names = ['Aland Islands',
                'Denmark',
                'Finland',
                'Faroe Islands',
                'Iceland',
                'Norway',
                'Sweden']

# subset Scandinavian countries
scandi_countries = countries.loc[countries.admin.isin(scandi_names),['admin','type','geometry']]

# ======= MERGE DATASETS =======
scandi_n_comms['admin'] = scandi_names
scandi_countries = pd.merge(scandi_countries, scandi_n_comms)

# ======= CREATE MAP =======
fig, ax = plt.subplots(figsize=(10, 10))

scandi_countries.plot(ax=ax,
                      column='n_communities',
                       cmap='BuPu',
                       legend=True,
                       edgecolor='black',
                       legend_kwds={'shrink':.8,
                                    'label': 'Number of Arctic communities', 
                                    'orientation': 'horizontal'
                                    }
                       )


ax.set_title('Arctic communities in Scandinavia',  fontsize=20)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

plt.show()
